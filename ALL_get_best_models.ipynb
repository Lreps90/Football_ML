# %%
import joblib
from sklearn.ensemble import RandomForestClassifier  # Example model type
import os
import re
import pandas as pd
import ast
import os
import random as rd
from datetime import datetime
from functools import reduce
from itertools import product
from operator import mul
import numpy as np
import pandas as pd
from scipy.stats import ttest_1samp
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler

# %%
# Define the directory to search for text files
folder_path = r"C:\Users\leere\PycharmProjects\Football_ML3\Leagues_ALL"

# Define a regex pattern to extract the relevant data
pattern = re.compile(
    r"League: \('([^']*)', '([^']*)'\), p-value: ([\d.]+), Threshold: ([\d.]+), "
    r"Staked: (\d+), Profit: [^\d-]*([-\d.]+), ROI: ([\d.]+)%, "
    r"Params: ({.*})"
)

# List to store extracted data
data = []

# Walk through the directory and subdirectories
for root, _, files in os.walk(folder_path):
    for file in files:
        if file.endswith(".txt"):  # Only process text files
            file_path = os.path.join(root, file)
            with open(file_path, "r", encoding="latin1") as f:
                for line in f:
                    match = pattern.search(line)
                    if match:
                        country, league, p_value, threshold, staked, profit, roi, params = match.groups()
                        data.append({
                            "Country": country,
                            "League": league,
                            "p-value": float(p_value),
                            "Threshold": float(threshold),
                            "Staked": int(staked),
                            "Profit": float(profit),
                            "ROI": float(roi),
                            "Params": params
                        })

# Create a DataFrame from the data
df = pd.DataFrame(data)

# %%
#Group the main DataFrame by 'League' and 'Sub-League'
grouped = df.groupby(['Country', 'League'])

# Create a list of DataFrames, one for each group
dataframes_list = [group for _, group in grouped]

# Optionally, name the DataFrames for reference
dataframe_names = [f"{name[0]}_{name[1]}" for name in grouped.groups.keys()]

# Optionally return the list of DataFrames and their names
dataframes_named = dict(zip(dataframe_names, dataframes_list))

# %%
# List to store rows with maximum profit from each group
max_profit_rows = []

# Iterate through each group
for name, group in df.groupby(['Country', 'League']):
    # Find the row with the maximum profit in the group
    max_row = group.loc[group['Profit'].idxmax()]
    max_profit_rows.append(max_row)

# Convert the result to a DataFrame
max_profit_df = pd.DataFrame(max_profit_rows)

# Display the resulting DataFrame
max_profit_df
# Out:
#               Country           League  p-value  Threshold  Staked  Profit  \
# 0           Argentina  Primera Divisio   0.3884       0.52      53    8.66
# 231535        Austria       Erste Liga   0.0844       0.56     147   16.99
# 611421        Belgium       Pro League   0.0187       0.65      77   15.58
# 731774         Brazil          Serie A   0.0350       0.50     170   29.94
# 906492       Bulgaria        Premier L   0.0504       0.52      82   19.43
# 1280814         Chile  Primera Divisio   0.2491       0.50      63    8.78
# 1299731         China       Chinese SL   0.0871       0.62      92   11.86
# 1759429       Croatia       Division 1   0.1737       0.53      57    9.65
# 2018663         Czech       Division 1   0.0918       0.51     104   14.17
# 2067219       Denmark      Superligaen   0.7365       0.55      55    2.19
# 2068477       England     Championship   0.2629       0.52     165   13.04
# 2085520       England       League One   0.0471       0.58     142   23.19
# 2548241       England       League Two   0.0361       0.53     133   20.92
# 2964757       England        Premier L   0.0013       0.57     127   25.99
# 3099581        France          Ligue 1   0.0642       0.50     152   20.10
# 3685822        France          Ligue 2   0.1178       0.70      54   12.78
# 3740178       Germany       3rd League   0.0112       0.66      53   14.05
# 3747262       Germany       Bundesliga   0.0078       0.63     122   21.33
# 4469852       Germany     Bundesliga 2   0.0262       0.55     133   18.78
# 4730418        Greece          Super L   0.0175       0.50      98   23.14
# 5073821       Hungary       Division 1   0.2398       0.52     132   11.72
# 5174019       Ireland        Premier D   0.3206       0.56      67    8.56
# 5204851        Israel   Premier League   0.8089       0.51      55    1.74
# 5312369         Italy          Serie A   0.0147       0.59     106   24.30
# 5787773         Italy          Serie B   0.0384       0.61     149   29.05
# 5949520         Japan        J. League   0.0587       0.53      69   15.48
# 5978494         Japan      J. League 2   0.1820       0.55      94   13.16
# 6017249        Mexico  Primera Divisio   0.2524       0.53      52    6.75
# 6022827   Netherlands   Eerste Divisie   0.3535       0.78     100    6.83
# 6956977   Netherlands       Eredivisie   0.0155       0.51     175   24.32
# 7850048        Norway      Eliteserien   0.0004       0.67      53   16.38
# 8193342        Poland      Ekstraklasa   0.0623       0.62     120   20.26
# 8551262      Portugal       Primeira L   0.0062       0.51     116   25.55
# 8962921       Romania           Liga 1   0.3535       0.50      51    7.07
# 8998759      Scotland     Championship   0.0305       0.51      52   14.11
# 9109448      Scotland        Premier L   0.0861       0.53      81   13.69
# 9365590      Slovakia        Superliga   0.1815       0.52      55    9.11
# 9562912      Slovenia         Prvaliga   0.0144       0.56      68   18.00
# 9751786    SouthKorea         K-League   0.0138       0.55      75   20.77
# 10078688        Spain          Primera   0.0316       0.52      83   18.54
# 10199387        Spain          Segunda   0.0653       0.53      70   19.17
# 10201983       Sweden      Allsvenskan   0.0079       0.76      70   16.77
# 10679200       Sweden       Superettan   0.1221       0.72      56    9.70
# 10749177  Switzerland     Super League   0.6602       0.64      63    2.84
# 10751124       Turkey        Super Lig   0.0100       0.63      59   16.01
#
#            ROI                                             Params
# 0         16.3  {'model__n_estimators': 100, 'model__max_depth...
# 231535    11.6  {'model__n_estimators': 21, 'model__max_depth'...
# 611421    20.2  {'model__n_estimators': 23, 'model__max_depth'...
# 731774    17.6  {'model__n_estimators': 100, 'model__max_depth...
# 906492    23.7  {'model__n_estimators': 200, 'model__max_depth...
# 1280814   13.9  {'model__n_estimators': 11, 'model__max_depth'...
# 1299731   12.9  {'model__n_estimators': 50, 'model__max_depth'...
# 1759429   16.9  {'model__n_estimators': 50, 'model__max_depth'...
# 2018663   13.6  {'model__n_estimators': 10, 'model__max_depth'...
# 2067219    4.0  {'model__n_estimators': 25, 'model__max_depth'...
# 2068477    7.9  {'model__n_estimators': 32, 'model__max_depth'...
# 2085520   16.3  {'model__n_estimators': 18, 'model__max_depth'...
# 2548241   15.7  {'model__n_estimators': 42, 'model__max_depth'...
# 2964757   20.5  {'model__n_estimators': 24, 'model__max_depth'...
# 3099581   13.2  {'model__n_estimators': 200, 'model__max_depth...
# 3685822   23.7  {'model__n_estimators': 36, 'model__max_depth'...
# 3740178   26.5  {'model__n_estimators': 11, 'model__max_depth'...
# 3747262   17.5  {'model__n_estimators': 29, 'model__max_depth'...
# 4469852   14.1  {'model__n_estimators': 30, 'model__max_depth'...
# 4730418   23.6  {'model__n_estimators': 30, 'model__max_depth'...
# 5073821    8.9  {'model__n_estimators': 50, 'model__max_depth'...
# 5174019   12.8  {'model__n_estimators': 50, 'model__max_depth'...
# 5204851    3.2  {'model__n_estimators': 50, 'model__max_depth'...
# 5312369   22.9  {'model__n_estimators': 17, 'model__max_depth'...
# 5787773   19.5  {'model__n_estimators': 47, 'model__max_depth'...
# 5949520   22.4  {'model__n_estimators': 49, 'model__max_depth'...
# 5978494   14.0  {'model__n_estimators': 50, 'model__max_depth'...
# 6017249   13.0  {'model__n_estimators': 71, 'model__max_depth'...
# 6022827    6.8  {'model__n_estimators': 23, 'model__max_depth'...
# 6956977   13.9  {'model__n_estimators': 36, 'model__max_depth'...
# 7850048   30.9  {'model__n_estimators': 38, 'model__max_depth'...
# 8193342   16.9  {'model__n_estimators': 33, 'model__max_depth'...
# 8551262   22.0  {'model__n_estimators': 18, 'model__max_depth'...
# 8962921   13.9  {'model__n_estimators': 19, 'model__max_depth'...
# 8998759   27.1  {'model__n_estimators': 19, 'model__max_depth'...
# 9109448   16.9  {'model__n_estimators': 11, 'model__max_depth'...
# 9365590   16.6  {'model__n_estimators': 25, 'model__max_depth'...
# 9562912   26.5  {'model__n_estimators': 45, 'model__max_depth'...
# 9751786   27.7  {'model__n_estimators': 11, 'model__max_depth'...
# 10078688  22.3  {'model__n_estimators': 200, 'model__max_depth...
# 10199387  27.4  {'model__n_estimators': 26, 'model__max_depth'...
# 10201983  24.0  {'model__n_estimators': 200, 'model__max_depth...
# 10679200  17.3  {'model__n_estimators': 21, 'model__max_depth'...
# 10749177   4.5  {'model__n_estimators': 11, 'model__max_depth'...
# 10751124  27.1  {'model__n_estimators': 50, 'model__max_depth'...

# %%
# # Directory to save the models
# models_dir = "TOP_5_MODELS"  # Change this to your desired directory
# os.makedirs(models_dir, exist_ok=True)
#
# # Iterate through each row in the DataFrame
# for index, row in max_profit_df.iterrows():
#     # Parse the parameters from the Params column
#     params = ast.literal_eval(row['Params'])  # Safely convert string to dictionary
#
#     # Remove the 'model__' prefix from each parameter key
#     cleaned_params = {key.replace('model__', ''): value for key, value in params.items()}
#
#     # Instantiate the model with the cleaned parameters
#     model = RandomForestClassifier(**cleaned_params)
#
#     # Save the model with a unique filename based on League and Sub-League
#     model_filename = f"{models_dir}/{row['Country']}_{row['League']}_model.pkl"
#     joblib.dump(model, model_filename)
#     print(f"Saved model for {row['Country']} - {row['League']} to {model_filename}")

import os
import ast
import joblib
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# Directory to save the models
models_dir = "ALL_MODELS"  # Change this to your desired directory
os.makedirs(models_dir, exist_ok=True)

# Iterate through each row in the DataFrame
for index, row in max_profit_df.iterrows():
    # Parse the parameters from the Params column
    params = ast.literal_eval(row['Params'])  # Safely convert string to dictionary

    # Determine the model type based on parameters
    if 'hidden_layer_sizes' in str(params):
        model_type = 'MLP'
    else:
        model_type = 'RandomForest'

    # Remove the 'model__' prefix from each parameter key
    cleaned_params = {key.replace('model__', ''): value for key, value in params.items()}

    # Instantiate the appropriate model
    if model_type == 'MLP':
        model = MLPClassifier(**cleaned_params, random_state=42)
    else:
        model = RandomForestClassifier(**cleaned_params, random_state=42)

    # Save the model with a unique filename based on League and Sub-League
    model_filename = f"{models_dir}/{row['Country']}_{row['League']}_model.pkl"
    joblib.dump(model, model_filename)
    print(f"Saved {model_type} model for {row['Country']} - {row['League']} to {model_filename}")
# Out:
# Saved RandomForest model for Argentina - Primera Divisio to ALL_MODELS/Argentina_Primera Divisio_model.pkl
# Saved RandomForest model for Austria - Erste Liga to ALL_MODELS/Austria_Erste Liga_model.pkl
# Saved RandomForest model for Belgium - Pro League to ALL_MODELS/Belgium_Pro League_model.pkl
# Saved RandomForest model for Brazil - Serie A to ALL_MODELS/Brazil_Serie A_model.pkl
# Saved RandomForest model for Bulgaria - Premier L to ALL_MODELS/Bulgaria_Premier L_model.pkl
# Saved RandomForest model for Chile - Primera Divisio to ALL_MODELS/Chile_Primera Divisio_model.pkl
# Saved RandomForest model for China - Chinese SL to ALL_MODELS/China_Chinese SL_model.pkl
# Saved RandomForest model for Croatia - Division 1 to ALL_MODELS/Croatia_Division 1_model.pkl
# Saved RandomForest model for Czech - Division 1 to ALL_MODELS/Czech_Division 1_model.pkl
# Saved RandomForest model for Denmark - Superligaen to ALL_MODELS/Denmark_Superligaen_model.pkl
# Saved RandomForest model for England - Championship to ALL_MODELS/England_Championship_model.pkl
# Saved RandomForest model for England - League One to ALL_MODELS/England_League One_model.pkl
# Saved RandomForest model for England - League Two to ALL_MODELS/England_League Two_model.pkl
# Saved RandomForest model for England - Premier L to ALL_MODELS/England_Premier L_model.pkl
# Saved RandomForest model for France - Ligue 1 to ALL_MODELS/France_Ligue 1_model.pkl
# Saved RandomForest model for France - Ligue 2 to ALL_MODELS/France_Ligue 2_model.pkl
# Saved RandomForest model for Germany - 3rd League to ALL_MODELS/Germany_3rd League_model.pkl
# Saved RandomForest model for Germany - Bundesliga to ALL_MODELS/Germany_Bundesliga_model.pkl
# Saved RandomForest model for Germany - Bundesliga 2 to ALL_MODELS/Germany_Bundesliga 2_model.pkl
# Saved RandomForest model for Greece - Super L to ALL_MODELS/Greece_Super L_model.pkl
# Saved RandomForest model for Hungary - Division 1 to ALL_MODELS/Hungary_Division 1_model.pkl
# Saved RandomForest model for Ireland - Premier D to ALL_MODELS/Ireland_Premier D_model.pkl
# Saved RandomForest model for Israel - Premier League to ALL_MODELS/Israel_Premier League_model.pkl
# Saved RandomForest model for Italy - Serie A to ALL_MODELS/Italy_Serie A_model.pkl
# Saved RandomForest model for Italy - Serie B to ALL_MODELS/Italy_Serie B_model.pkl
# Saved RandomForest model for Japan - J. League to ALL_MODELS/Japan_J. League_model.pkl
# Saved RandomForest model for Japan - J. League 2 to ALL_MODELS/Japan_J. League 2_model.pkl
# Saved RandomForest model for Mexico - Primera Divisio to ALL_MODELS/Mexico_Primera Divisio_model.pkl
# Saved RandomForest model for Netherlands - Eerste Divisie to ALL_MODELS/Netherlands_Eerste Divisie_model.pkl
# Saved RandomForest model for Netherlands - Eredivisie to ALL_MODELS/Netherlands_Eredivisie_model.pkl
# Saved RandomForest model for Norway - Eliteserien to ALL_MODELS/Norway_Eliteserien_model.pkl
# Saved RandomForest model for Poland - Ekstraklasa to ALL_MODELS/Poland_Ekstraklasa_model.pkl
# Saved RandomForest model for Portugal - Primeira L to ALL_MODELS/Portugal_Primeira L_model.pkl
# Saved RandomForest model for Romania - Liga 1 to ALL_MODELS/Romania_Liga 1_model.pkl
# Saved RandomForest model for Scotland - Championship to ALL_MODELS/Scotland_Championship_model.pkl
# Saved RandomForest model for Scotland - Premier L to ALL_MODELS/Scotland_Premier L_model.pkl
# Saved RandomForest model for Slovakia - Superliga to ALL_MODELS/Slovakia_Superliga_model.pkl
# Saved RandomForest model for Slovenia - Prvaliga to ALL_MODELS/Slovenia_Prvaliga_model.pkl
# Saved RandomForest model for SouthKorea - K-League to ALL_MODELS/SouthKorea_K-League_model.pkl
# Saved RandomForest model for Spain - Primera to ALL_MODELS/Spain_Primera_model.pkl
# Saved RandomForest model for Spain - Segunda to ALL_MODELS/Spain_Segunda_model.pkl
# Saved RandomForest model for Sweden - Allsvenskan to ALL_MODELS/Sweden_Allsvenskan_model.pkl
# Saved RandomForest model for Sweden - Superettan to ALL_MODELS/Sweden_Superettan_model.pkl
# Saved RandomForest model for Switzerland - Super League to ALL_MODELS/Switzerland_Super League_model.pkl
# Saved RandomForest model for Turkey - Super Lig to ALL_MODELS/Turkey_Super Lig_model.pkl

# %%
# List of common encodings to try
encodings = ['utf-8', 'latin1', 'iso-8859-1', 'cp1252']

data = None
for encoding in encodings:
    try:
        data = pd.read_csv("GOAL_DATA_3.csv", encoding=encoding)
        print(f"Successfully read the file with encoding: {encoding}")
        break
    except UnicodeDecodeError:
        print(f"Failed to decode with encoding: {encoding}")

col_dict = {
    "country": "Country",
    "league": "League",
    "datameci": "Date",
    "etapa": "Round",
    "txtechipa1": "home_team",
    "txtechipa2": "away_team",
    "place1t": "Home_team_place_total",
    "place1a": "Home_team_place_home",
    "place2t": "Away_team_place_total",
    "place2d": "Away_team_place_away",
    "customh": "ELO_home",
    "customa": "ELO_away",
    "custom3": "FORM_home",
    "custom4": "FORM_away",
    "home_val": "home_win",
    "home_val_2": "home_win_15",
    "home_val_3": "home_o25",
    "home_val_4": "home_o35",
    "home_val_5": "home_scored",
    "away_val": "away_win",
    "away_val_2": "away_win_15",
    "away_val_3": "away_o25",
    "away_val_4": "away_o35",
    "away_val_5": "away_scored",
    "scor1": "home_goals",
    "scor2": "away_goals",
    "cotao": "o2.5_odds",
}

data = data.rename(columns=col_dict).filter(items=col_dict.values())
# Convert Date column to datetime type
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')

# Order by date
data = data.sort_values(by='Date')

data = data[data["Round"] >= 8]
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

data['total_goals'] = data['home_goals'] + data['away_goals']
data['over_2.5_goals'] = data['total_goals'].apply(lambda x: 1 if x > 2.5 else 0)

# Create unique tuples across 'Name' and 'City'
leagues = max_profit_df[['Country', 'League']].drop_duplicates().apply(tuple, axis=1).tolist()

data_ready = data.drop(columns=['home_team', 'away_team', 'home_goals', 'away_goals', 'total_goals', 'o2.5_odds', ])
# Out:
# Failed to decode with encoding: utf-8
# Successfully read the file with encoding: latin1

# %%
import ast
import joblib
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# Directory where models will be saved
models_dir = "ALL_MODELS"
os.makedirs(models_dir, exist_ok=True)

# Iterate through each league
for index, (country_name, league_name) in enumerate(leagues):
    # Filter data for the current league
    data_filtered = data_ready[(data_ready["Country"] == country_name) & (data_ready["League"] == league_name)]
    if data_filtered.empty:
        continue

    # Split the data into training and testing sets by date
    cut_off_date = data_filtered['Date'].quantile(0.8)
    train_data = data_filtered[data_filtered['Date'] <= cut_off_date]
    y_train = train_data["over_2.5_goals"]
    train_data = train_data.drop(columns=['Date', 'over_2.5_goals', 'League', 'Country'])
    test_data = data_filtered[data_filtered['Date'] > cut_off_date]
    y_test = test_data["over_2.5_goals"]
    test_data = test_data.drop(columns=['Date', 'over_2.5_goals', 'League', 'Country'])

    # Initialize the scaler
    scaler = StandardScaler()
    scaler.fit(train_data)
    train_data_scaled = scaler.transform(train_data)
    test_data_scaled = scaler.transform(test_data)

    # Extract parameters and threshold from max_profit_df
    params_str = max_profit_df['Params'].iloc[index]
    threshold = max_profit_df['Threshold'].iloc[index]

    # Convert the params from string to dictionary and clean the keys
    params = ast.literal_eval(params_str)
    cleaned_params = {key.replace('model__', ''): value for key, value in params.items()}

    # Determine the model type based on parameters
    if 'hidden_layer_sizes' in str(cleaned_params):
        model_type = 'MLP'
    else:
        model_type = 'RandomForest'

    # Remove the 'model__' prefix from each parameter key
    cleaned_params = {key.replace('model__', ''): value for key, value in params.items()}

    # Instantiate the appropriate model
    if model_type == 'MLP':
        model = MLPClassifier(**cleaned_params, random_state=42)
    else:
        model = RandomForestClassifier(**cleaned_params, random_state=42)

    print(f"Training model for {country_name} - {league_name}...")
    print(f"Params: {cleaned_params}, Threshold: {threshold}")

    model.fit(train_data_scaled, y_train)

    # Save the trained model along with its scaler and threshold
    model_filename = f"{models_dir}/{country_name}_{league_name}_model.pkl"
    joblib.dump({'model': model, 'scaler': scaler, 'threshold': threshold}, model_filename)
    print(f"Trained and saved model for {country_name} - {league_name} at {model_filename}")

    # Evaluate the model on the test data
    y_proba = model.predict_proba(test_data_scaled)[:, 1]  # Probabilities for the positive class
    y_pred = (y_proba >= threshold).astype(int)  # Apply the saved threshold

    # Simulate betting results
    profit_list = []
    profit = 0
    for idx, pred in enumerate(y_pred):
        if pred == 1:  # Bet placed
            odds = data.iloc[test_data.index[idx]]['o2.5_odds']
            profit_value = (odds - 1) if y_test.iloc[idx] == 1 else -1
            profit_list.append(profit_value)
            profit += profit_value

    # Calculate betting performance metrics
    total_stake = len(profit_list)
    roi = (profit / total_stake) * 100 if total_stake > 0 else 0

    # Print results
    print(f"{league_name}")
    print(f"  Staked: {total_stake}")
    print(f"  Profit: £{profit:.2f}")
    print(f"  ROI: {roi:.1f}%")
# Out:
# Training model for Argentina - Primera Divisio...
# Params: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 20, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False, 'class_weight': 'balanced'}, Threshold: 0.52
# Trained and saved model for Argentina - Primera Divisio at ALL_MODELS/Argentina_Primera Divisio_model.pkl
# Primera Divisio
#   Staked: 53
#   Profit: £8.66
#   ROI: 16.3%
# Training model for Austria - Erste Liga...
# Params: {'n_estimators': 21, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 7, 'min_samples_leaf': 3, 'bootstrap': True}, Threshold: 0.56
# Trained and saved model for Austria - Erste Liga at ALL_MODELS/Austria_Erste Liga_model.pkl
# Erste Liga
#   Staked: 147
#   Profit: £16.99
#   ROI: 11.6%
# Training model for Belgium - Pro League...
# Params: {'n_estimators': 23, 'max_depth': 30, 'max_features': 'sqrt', 'min_samples_split': 8, 'min_samples_leaf': 16, 'bootstrap': True}, Threshold: 0.65
# Trained and saved model for Belgium - Pro League at ALL_MODELS/Belgium_Pro League_model.pkl
# Pro League
#   Staked: 77
#   Profit: £15.58
#   ROI: 20.2%
# Training model for Brazil - Serie A...
# Params: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced_subsample'}, Threshold: 0.5
# Trained and saved model for Brazil - Serie A at ALL_MODELS/Brazil_Serie A_model.pkl
# Serie A
#   Staked: 170
#   Profit: £29.94
#   ROI: 17.6%
# Training model for Bulgaria - Premier L...
# Params: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 20, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': False, 'class_weight': None}, Threshold: 0.52
# Trained and saved model for Bulgaria - Premier L at ALL_MODELS/Bulgaria_Premier L_model.pkl
# Premier L
#   Staked: 82
#   Profit: £19.43
#   ROI: 23.7%
# Training model for Chile - Primera Divisio...
# Params: {'n_estimators': 11, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 3, 'min_samples_leaf': 3, 'bootstrap': False}, Threshold: 0.5
# Trained and saved model for Chile - Primera Divisio at ALL_MODELS/Chile_Primera Divisio_model.pkl
# Primera Divisio
#   Staked: 63
#   Profit: £8.78
#   ROI: 13.9%
# Training model for China - Chinese SL...
# Params: {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced'}, Threshold: 0.62
# Trained and saved model for China - Chinese SL at ALL_MODELS/China_Chinese SL_model.pkl
# Chinese SL
#   Staked: 92
#   Profit: £11.86
#   ROI: 12.9%
# Training model for Croatia - Division 1...
# Params: {'n_estimators': 50, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced'}, Threshold: 0.53
# Trained and saved model for Croatia - Division 1 at ALL_MODELS/Croatia_Division 1_model.pkl
# Division 1
#   Staked: 57
#   Profit: £9.65
#   ROI: 16.9%
# Training model for Czech - Division 1...
# Params: {'n_estimators': 10, 'max_depth': 4, 'max_features': 'sqrt', 'min_samples_split': 7, 'min_samples_leaf': 16, 'bootstrap': False}, Threshold: 0.51
# Trained and saved model for Czech - Division 1 at ALL_MODELS/Czech_Division 1_model.pkl
# Division 1
#   Staked: 104
#   Profit: £14.17
#   ROI: 13.6%
# Training model for Denmark - Superligaen...
# Params: {'n_estimators': 25, 'max_depth': 10, 'max_features': None, 'min_samples_split': 10, 'min_samples_leaf': 3, 'bootstrap': True}, Threshold: 0.55
# Trained and saved model for Denmark - Superligaen at ALL_MODELS/Denmark_Superligaen_model.pkl
# Superligaen
#   Staked: 55
#   Profit: £2.19
#   ROI: 4.0%
# Training model for England - Championship...
# Params: {'n_estimators': 32, 'max_depth': 26, 'max_features': 'sqrt', 'min_samples_split': 41, 'min_samples_leaf': 11, 'bootstrap': True}, Threshold: 0.52
# Trained and saved model for England - Championship at ALL_MODELS/England_Championship_model.pkl
# Championship
#   Staked: 165
#   Profit: £13.04
#   ROI: 7.9%
# Training model for England - League One...
# Params: {'n_estimators': 18, 'max_depth': 40, 'max_features': 'sqrt', 'min_samples_split': 8, 'min_samples_leaf': 1, 'bootstrap': False}, Threshold: 0.58
# Trained and saved model for England - League One at ALL_MODELS/England_League One_model.pkl
# League One
#   Staked: 142
#   Profit: £23.19
#   ROI: 16.3%
# Training model for England - League Two...
# Params: {'n_estimators': 42, 'max_depth': 10, 'max_features': None, 'min_samples_split': 11, 'min_samples_leaf': 3, 'bootstrap': True}, Threshold: 0.53
# Trained and saved model for England - League Two at ALL_MODELS/England_League Two_model.pkl
# League Two
#   Staked: 133
#   Profit: £20.92
#   ROI: 15.7%
# Training model for England - Premier L...
# Params: {'n_estimators': 24, 'max_depth': 23, 'max_features': 'sqrt', 'min_samples_split': 4, 'min_samples_leaf': 4, 'bootstrap': False}, Threshold: 0.57
# Trained and saved model for England - Premier L at ALL_MODELS/England_Premier L_model.pkl
# Premier L
#   Staked: 127
#   Profit: £25.99
#   ROI: 20.5%
# Training model for France - Ligue 1...
# Params: {'n_estimators': 200, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False, 'class_weight': 'balanced'}, Threshold: 0.5
# Trained and saved model for France - Ligue 1 at ALL_MODELS/France_Ligue 1_model.pkl
# Ligue 1
#   Staked: 152
#   Profit: £20.10
#   ROI: 13.2%
# Training model for France - Ligue 2...
# Params: {'n_estimators': 36, 'max_depth': 24, 'max_features': None, 'min_samples_split': 3, 'min_samples_leaf': 14, 'bootstrap': False}, Threshold: 0.7
# Trained and saved model for France - Ligue 2 at ALL_MODELS/France_Ligue 2_model.pkl
# Ligue 2
#   Staked: 54
#   Profit: £12.78
#   ROI: 23.7%
# Training model for Germany - 3rd League...
# Params: {'n_estimators': 11, 'max_depth': 30, 'max_features': 'sqrt', 'min_samples_split': 17, 'min_samples_leaf': 4, 'bootstrap': True}, Threshold: 0.66
# Trained and saved model for Germany - 3rd League at ALL_MODELS/Germany_3rd League_model.pkl
# 3rd League
#   Staked: 53
#   Profit: £14.05
#   ROI: 26.5%
# Training model for Germany - Bundesliga...
# Params: {'n_estimators': 29, 'max_depth': 22, 'max_features': None, 'min_samples_split': 8, 'min_samples_leaf': 1, 'bootstrap': True}, Threshold: 0.63
# Trained and saved model for Germany - Bundesliga at ALL_MODELS/Germany_Bundesliga_model.pkl
# Bundesliga
#   Staked: 122
#   Profit: £21.33
#   ROI: 17.5%
# Training model for Germany - Bundesliga 2...
# Params: {'n_estimators': 30, 'max_depth': 10, 'max_features': None, 'min_samples_split': 10, 'min_samples_leaf': 2, 'bootstrap': True}, Threshold: 0.55
# Trained and saved model for Germany - Bundesliga 2 at ALL_MODELS/Germany_Bundesliga 2_model.pkl
# Bundesliga 2
#   Staked: 133
#   Profit: £18.78
#   ROI: 14.1%
# Training model for Greece - Super L...
# Params: {'n_estimators': 30, 'max_depth': 14, 'max_features': None, 'min_samples_split': 27, 'min_samples_leaf': 3, 'bootstrap': False}, Threshold: 0.5
# Trained and saved model for Greece - Super L at ALL_MODELS/Greece_Super L_model.pkl
# Super L
#   Staked: 98
#   Profit: £23.14
#   ROI: 23.6%
# Training model for Hungary - Division 1...
# Params: {'n_estimators': 50, 'max_depth': 9, 'max_features': None, 'min_samples_split': 8, 'min_samples_leaf': 19, 'bootstrap': False}, Threshold: 0.52
# Trained and saved model for Hungary - Division 1 at ALL_MODELS/Hungary_Division 1_model.pkl
# Division 1
#   Staked: 132
#   Profit: £11.72
#   ROI: 8.9%
# Training model for Ireland - Premier D...
# Params: {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': None, 'bootstrap': False, 'class_weight': 'balanced'}, Threshold: 0.56
# Trained and saved model for Ireland - Premier D at ALL_MODELS/Ireland_Premier D_model.pkl
# Premier D
#   Staked: 67
#   Profit: £8.56
#   ROI: 12.8%
# Training model for Israel - Premier League...
# Params: {'n_estimators': 50, 'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced'}, Threshold: 0.51
# Trained and saved model for Israel - Premier League at ALL_MODELS/Israel_Premier League_model.pkl
# Premier League
#   Staked: 55
#   Profit: £1.74
#   ROI: 3.2%
# Training model for Italy - Serie A...
# Params: {'n_estimators': 17, 'max_depth': 11, 'max_features': 'sqrt', 'min_samples_split': 6, 'min_samples_leaf': 1, 'bootstrap': True}, Threshold: 0.59
# Trained and saved model for Italy - Serie A at ALL_MODELS/Italy_Serie A_model.pkl
# Serie A
#   Staked: 106
#   Profit: £24.30
#   ROI: 22.9%
# Training model for Italy - Serie B...
# Params: {'n_estimators': 47, 'max_depth': 42, 'max_features': None, 'min_samples_split': 9, 'min_samples_leaf': 1, 'bootstrap': False}, Threshold: 0.61
# Trained and saved model for Italy - Serie B at ALL_MODELS/Italy_Serie B_model.pkl
# Serie B
#   Staked: 149
#   Profit: £29.05
#   ROI: 19.5%
# Training model for Japan - J. League...
# Params: {'n_estimators': 49, 'max_depth': 44, 'max_features': None, 'min_samples_split': 7, 'min_samples_leaf': 3, 'bootstrap': True}, Threshold: 0.53
# Trained and saved model for Japan - J. League at ALL_MODELS/Japan_J. League_model.pkl
# J. League
#   Staked: 69
#   Profit: £15.48
#   ROI: 22.4%
# Training model for Japan - J. League 2...
# Params: {'n_estimators': 50, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced_subsample'}, Threshold: 0.55
# Trained and saved model for Japan - J. League 2 at ALL_MODELS/Japan_J. League 2_model.pkl
# J. League 2
#   Staked: 94
#   Profit: £13.16
#   ROI: 14.0%
# Training model for Mexico - Primera Divisio...
# Params: {'n_estimators': 71, 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 43, 'min_samples_leaf': 17, 'bootstrap': False}, Threshold: 0.53
# Trained and saved model for Mexico - Primera Divisio at ALL_MODELS/Mexico_Primera Divisio_model.pkl
# Primera Divisio
#   Staked: 52
#   Profit: £6.75
#   ROI: 13.0%
# Training model for Netherlands - Eerste Divisie...
# Params: {'n_estimators': 23, 'max_depth': 19, 'max_features': None, 'min_samples_split': 10, 'min_samples_leaf': 20, 'bootstrap': False}, Threshold: 0.78
# Trained and saved model for Netherlands - Eerste Divisie at ALL_MODELS/Netherlands_Eerste Divisie_model.pkl
# Eerste Divisie
#   Staked: 100
#   Profit: £6.83
#   ROI: 6.8%
# Training model for Netherlands - Eredivisie...
# Params: {'n_estimators': 36, 'max_depth': 28, 'max_features': None, 'min_samples_split': 28, 'min_samples_leaf': 8, 'bootstrap': False}, Threshold: 0.51
# Trained and saved model for Netherlands - Eredivisie at ALL_MODELS/Netherlands_Eredivisie_model.pkl
# Eredivisie
#   Staked: 175
#   Profit: £24.32
#   ROI: 13.9%
# Training model for Norway - Eliteserien...
# Params: {'n_estimators': 38, 'max_depth': 13, 'max_features': 'sqrt', 'min_samples_split': 34, 'min_samples_leaf': 7, 'bootstrap': True}, Threshold: 0.67
# Trained and saved model for Norway - Eliteserien at ALL_MODELS/Norway_Eliteserien_model.pkl
# Eliteserien
#   Staked: 53
#   Profit: £16.38
#   ROI: 30.9%
# Training model for Poland - Ekstraklasa...
# Params: {'n_estimators': 33, 'max_depth': 10, 'max_features': None, 'min_samples_split': 23, 'min_samples_leaf': 4, 'bootstrap': False}, Threshold: 0.62
# Trained and saved model for Poland - Ekstraklasa at ALL_MODELS/Poland_Ekstraklasa_model.pkl
# Ekstraklasa
#   Staked: 120
#   Profit: £20.26
#   ROI: 16.9%
# Training model for Portugal - Primeira L...
# Params: {'n_estimators': 18, 'max_depth': 30, 'max_features': None, 'min_samples_split': 15, 'min_samples_leaf': 3, 'bootstrap': True}, Threshold: 0.51
# Trained and saved model for Portugal - Primeira L at ALL_MODELS/Portugal_Primeira L_model.pkl
# Primeira L
#   Staked: 116
#   Profit: £25.55
#   ROI: 22.0%
# Training model for Romania - Liga 1...
# Params: {'n_estimators': 19, 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_split': 10, 'min_samples_leaf': 11, 'bootstrap': True}, Threshold: 0.5
# Trained and saved model for Romania - Liga 1 at ALL_MODELS/Romania_Liga 1_model.pkl
# Liga 1
#   Staked: 51
#   Profit: £7.07
#   ROI: 13.9%
# Training model for Scotland - Championship...
# Params: {'n_estimators': 19, 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 39, 'min_samples_leaf': 4, 'bootstrap': True}, Threshold: 0.51
# Trained and saved model for Scotland - Championship at ALL_MODELS/Scotland_Championship_model.pkl
# Championship
#   Staked: 52
#   Profit: £14.11
#   ROI: 27.1%
# Training model for Scotland - Premier L...
# Params: {'n_estimators': 11, 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_split': 25, 'min_samples_leaf': 5, 'bootstrap': False}, Threshold: 0.53
# Trained and saved model for Scotland - Premier L at ALL_MODELS/Scotland_Premier L_model.pkl
# Premier L
#   Staked: 81
#   Profit: £13.69
#   ROI: 16.9%
# Training model for Slovakia - Superliga...
# Params: {'n_estimators': 25, 'max_depth': 9, 'max_features': 'sqrt', 'min_samples_split': 7, 'min_samples_leaf': 3, 'bootstrap': True}, Threshold: 0.52
# Trained and saved model for Slovakia - Superliga at ALL_MODELS/Slovakia_Superliga_model.pkl
# Superliga
#   Staked: 55
#   Profit: £9.11
#   ROI: 16.6%
# Training model for Slovenia - Prvaliga...
# Params: {'n_estimators': 45, 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_split': 3, 'min_samples_leaf': 1, 'bootstrap': True}, Threshold: 0.56
# Trained and saved model for Slovenia - Prvaliga at ALL_MODELS/Slovenia_Prvaliga_model.pkl
# Prvaliga
#   Staked: 68
#   Profit: £18.00
#   ROI: 26.5%
# Training model for SouthKorea - K-League...
# Params: {'n_estimators': 11, 'max_depth': 13, 'max_features': 'sqrt', 'min_samples_split': 2, 'min_samples_leaf': 3, 'bootstrap': True}, Threshold: 0.55
# Trained and saved model for SouthKorea - K-League at ALL_MODELS/SouthKorea_K-League_model.pkl
# K-League
#   Staked: 75
#   Profit: £20.77
#   ROI: 27.7%
# Training model for Spain - Primera...
# Params: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': 'balanced'}, Threshold: 0.52
# Trained and saved model for Spain - Primera at ALL_MODELS/Spain_Primera_model.pkl
# Primera
#   Staked: 83
#   Profit: £18.54
#   ROI: 22.3%
# Training model for Spain - Segunda...
# Params: {'n_estimators': 26, 'max_depth': 18, 'max_features': 'sqrt', 'min_samples_split': 2, 'min_samples_leaf': 1, 'bootstrap': True}, Threshold: 0.53
# Trained and saved model for Spain - Segunda at ALL_MODELS/Spain_Segunda_model.pkl
# Segunda
#   Staked: 70
#   Profit: £19.17
#   ROI: 27.4%
# Training model for Sweden - Allsvenskan...
# Params: {'n_estimators': 200, 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'bootstrap': False, 'class_weight': 'balanced'}, Threshold: 0.76
# Trained and saved model for Sweden - Allsvenskan at ALL_MODELS/Sweden_Allsvenskan_model.pkl
# Allsvenskan
#   Staked: 70
#   Profit: £16.77
#   ROI: 24.0%
# Training model for Sweden - Superettan...
# Params: {'n_estimators': 21, 'max_depth': 12, 'max_features': None, 'min_samples_split': 7, 'min_samples_leaf': 4, 'bootstrap': False}, Threshold: 0.72
# Trained and saved model for Sweden - Superettan at ALL_MODELS/Sweden_Superettan_model.pkl
# Superettan
#   Staked: 56
#   Profit: £9.70
#   ROI: 17.3%
# Training model for Switzerland - Super League...
# Params: {'n_estimators': 11, 'max_depth': 26, 'max_features': 'sqrt', 'min_samples_split': 6, 'min_samples_leaf': 2, 'bootstrap': True}, Threshold: 0.64
# Trained and saved model for Switzerland - Super League at ALL_MODELS/Switzerland_Super League_model.pkl
# Super League
#   Staked: 63
#   Profit: £2.84
#   ROI: 4.5%
# Training model for Turkey - Super Lig...
# Params: {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': True, 'class_weight': None}, Threshold: 0.63
# Trained and saved model for Turkey - Super Lig at ALL_MODELS/Turkey_Super Lig_model.pkl
# Super Lig
#   Staked: 59
#   Profit: £16.01
#   ROI: 27.1%
