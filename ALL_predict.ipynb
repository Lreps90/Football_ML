# %%
import joblib
import pandas as pd

# %%
file_path = r"C:\Users\leere\OneDrive\Desktop\RAW DATA\GOALS_LIVE.CSV"

# List of common encodings to try
encodings = ['utf-8', 'latin1', 'iso-8859-1', 'cp1252']

data = None
for encoding in encodings:
    try:
        data = pd.read_csv(file_path, encoding=encoding)
        print(f"Successfully read the file with encoding: {encoding}")
        break
    except UnicodeDecodeError:
        print(f"Failed to decode with encoding: {encoding}")

col_dict = {
    "country": "Country",
    "league": "League",
    "datameci": "Date",
    "etapa": "Round",
    "txtechipa1": "home_team",
    "txtechipa2": "away_team",
    "place1t": "Home_team_place_total",
    "place1a": "Home_team_place_home",
    "place2t": "Away_team_place_total",
    "place2d": "Away_team_place_away",
    "customh": "ELO_home",
    "customa": "ELO_away",
    "custom3": "FORM_home",
    "custom4": "FORM_away",
    "home_val": "home_win",
    "home_val_2": "home_win_15",
    "home_val_3": "home_o25",
    "home_val_4": "home_o35",
    "home_val_5": "home_scored",
    "away_val": "away_win",
    "away_val_2": "away_win_15",
    "away_val_3": "away_o25",
    "away_val_4": "away_o35",
    "away_val_5": "away_scored",
    "scor1": "home_goals",
    "scor2": "away_goals",
    "cotao": "o2.5_odds",
}

data = data.rename(columns=col_dict).filter(items=col_dict.values())
# Convert Date column to datetime type
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')

# Order by date
data = data.sort_values(by='Date')

data = data[data["Round"] >= 8]
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

cols_to_drop = ['Date','home_team', 'away_team', 'home_goals', 'away_goals', 'o2.5_odds']

data_ready =data.drop(columns=cols_to_drop)
data_ready
# Out:
# Successfully read the file with encoding: utf-8
#          Country          League  Round  Home_team_place_total  \
# 0    Netherlands  Eerste Divisie     20                     20
# 1        Germany      3rd League     19                      5
# 2        England      League One     21                     22
# 3        Romania          Liga 1     21                      6
# 4        England      League One     21                      5
# ..           ...             ...    ...                    ...
# 192        Italy         Serie A     17                     20
# 193      Belgium      Pro League     19                      9
# 194      Belgium      Pro League     19                      5
# 195       Greece         Super L     16                     11
# 196       Israel  Premier League     15                      7
#
#      Home_team_place_home  Away_team_place_total  Away_team_place_away  \
# 0                      20                      7                     6
# 1                       4                      1                     3
# 2                      16                      4                     5
# 3                       7                      1                     3
# 4                       5                     13                    17
# ..                    ...                    ...                   ...
# 192                    17                     18                    17
# 193                     5                      6                     6
# 194                     3                      2                     1
# 195                     9                      6                     5
# 196                     3                     12                    10
#
#      ELO_home  ELO_away  FORM_home  ...  home_win  home_win_15  home_o25  \
# 0      1152.0    1430.0       -4.0  ...    10.000        0.000    60.000
# 1      1480.0    1536.0       10.0  ...    55.556       22.222    66.667
# 2      1109.0    1322.0        2.0  ...    33.333       22.222    22.222
# 3      1993.0    2015.0       13.0  ...    50.000       30.000    20.000
# 4      1275.0    1161.0        6.0  ...    60.000       50.000    40.000
# ..        ...       ...        ...  ...       ...          ...       ...
# 192    1602.0    1635.0       -5.0  ...    28.571       14.286    42.857
# 193    1836.0    1931.0        0.0  ...    55.556        0.000    33.333
# 194    2044.0    2079.0        7.0  ...    66.667       44.444    66.667
# 195    1791.0    1863.0        6.0  ...    28.571        0.000    71.429
# 196    1979.0    1860.0       18.0  ...    57.143       28.571    42.857
#
#      home_o35  home_scored  away_win  away_win_15  away_o25  away_o35  \
# 0      40.000        0.700    55.556       11.111    77.778    44.444
# 1      33.333        2.111    55.556       33.333    66.667    44.444
# 2      22.222        1.444    44.444       33.333    55.556    22.222
# 3       0.000        1.200    40.000       20.000    40.000    20.000
# 4      40.000        1.800    25.000       12.500    87.500    50.000
# ..        ...          ...       ...          ...       ...       ...
# 192    28.571        1.143    14.286        0.000    42.857    28.571
# 193     0.000        1.000    22.222       11.111    44.444    33.333
# 194    44.444        1.889    55.556       11.111    66.667    22.222
# 195    57.143        1.429    42.857       14.286    14.286     0.000
# 196    14.286        1.286    16.667       16.667    83.333    66.667
#
#      away_scored
# 0          1.444
# 1          1.778
# 2          1.556
# 3          1.300
# 4          1.500
# ..           ...
# 192        1.000
# 193        1.000
# 194        1.667
# 195        1.000
# 196        1.667
#
# [197 rows x 21 columns]

# %%
# import pandas as pd
#
# # Directory where models are saved
# models_dir = "TOP_5_MODELS"
#
# # Group unseen data by League and Sub-League
# grouped_data = data_ready.groupby(['Country', 'League'])
#
# # Dictionary to store predictions
# predictions = {}
#
# # Iterate through each group in the unseen data
# for (country, league), group in grouped_data:
#     # Construct the model filename
#     model_filename = f"{models_dir}/{country}_{league}_model.pkl"
#
#     try:
#         # Load the corresponding model
#         saved_data = joblib.load(model_filename)  # Load the entire dictionary
#         model = saved_data['model']  # Extract the model
#         scaler = saved_data['scaler']  # Extract the scaler
#         threshold = saved_data['threshold']  # Extract the threshold
#
#         # Extract features for prediction (exclude grouping columns)
#         X = group.drop(columns=['Country', 'League'])
#
#         # Scale the features
#         X_scaled = scaler.transform(X)
#
#         # Make probability predictions using the model
#         y_proba = model.predict_proba(X_scaled)[:, 1]  # Positive class probabilities
#
#         # Filter predictions based on the threshold
#         group['Probability'] = y_proba
#         group['Prediction'] = (y_proba >= threshold).astype(int)
#
#         # Add filtered predictions to the dictionary
#         predictions[(country, league)] = group[group['Prediction'] == 1]
#         print(f"Filtered predictions made for {country} - {league}")
#
#     except FileNotFoundError:
#         print(f"Model not found for {country} - {league}. Skipping...")
#
#     except Exception as e:
#         print(f"Error processing {country} - {league}: {e}")
#
# # Combine all predictions into a single DataFrame
# if predictions:
#     all_predictions = pd.concat(predictions.values(), ignore_index=True)
#     print("\nAll Predictions as a DataFrame:")
#     print(all_predictions)
# else:
#     print("No predictions available.")

import pandas as pd
import joblib

# Directory where models are saved
models_dir = "ALL_MODELS"

# Group unseen data by League and Sub-League
grouped_data = data_ready.groupby(['Country', 'League'])

# Dictionary to store predictions
predictions = {}

# Iterate through each group in the unseen data
for (country, league), group in grouped_data:
    # Construct the model filename
    model_filename = f"{models_dir}/{country}_{league}_model.pkl"

    try:
        # Load the corresponding model
        saved_data = joblib.load(model_filename)  # Load the entire dictionary
        model = saved_data['model']  # Extract the model
        scaler = saved_data['scaler']  # Extract the scaler
        threshold = saved_data['threshold']  # Extract the threshold

        # Extract features for prediction (exclude grouping columns)
        X = group.drop(columns=['Country', 'League'])

        # Scale the features
        X_scaled = scaler.transform(X)

        # Make probability predictions using the model
        y_proba = model.predict_proba(X_scaled)[:, 1]  # Positive class probabilities

        # Filter predictions based on the threshold
        group['Probability'] = y_proba
        group['Prediction'] = (y_proba >= threshold).astype(int)

        # Keep only rows where Prediction == 1
        filtered_predictions = group[group['Prediction'] == 1]

        # Add `home_team` and `away_team` from the original `data`
        game_info = data.loc[filtered_predictions.index, ['home_team', 'away_team', 'Date']]
        filtered_predictions = pd.concat([game_info, filtered_predictions], axis=1)

        # Add filtered predictions to the dictionary
        predictions[(country, league)] = filtered_predictions
        print(f"Filtered predictions made for {country} - {league}")

    except FileNotFoundError:
        print(f"Model not found for {country} - {league}. Skipping...")

    except Exception as e:
        print(f"Error processing {country} - {league}: {e}")

# Combine all predictions into a single DataFrame
if predictions:
    all_predictions = pd.concat(predictions.values(), ignore_index=True)
    print("\nAll Predictions as a DataFrame:")
    print(all_predictions)
else:
    print("No predictions available.")
# Out:
# Model not found for Australia - A-League. Skipping...
# Filtered predictions made for Belgium - Pro League
# Filtered predictions made for Croatia - Division 1
# Filtered predictions made for England - Championship
# Filtered predictions made for England - League One
# Filtered predictions made for England - League Two
# Filtered predictions made for England - Premier L
# Filtered predictions made for Germany - 3rd League
# Filtered predictions made for Germany - Bundesliga
# Filtered predictions made for Germany - Bundesliga 2
# Filtered predictions made for Greece - Super L
# Filtered predictions made for Israel - Premier League
# Filtered predictions made for Italy - Serie A
# Filtered predictions made for Italy - Serie B
# Filtered predictions made for Netherlands - Eerste Divisie
# Filtered predictions made for Netherlands - Eredivisie
# Filtered predictions made for Portugal - Primeira L
# Filtered predictions made for Romania - Liga 1
# Filtered predictions made for Scotland - Championship
# Filtered predictions made for Scotland - Premier L
# Filtered predictions made for Spain - Primera
# Filtered predictions made for Spain - Segunda
# Model not found for Turkey - 1. Lig. Skipping...
# Filtered predictions made for Turkey - Super Lig
#
# All Predictions as a DataFrame:
#               home_team            away_team       Date      Country  \
# 0                 Liege                 Gent 2024-12-22      Belgium
# 1                Gorica           Lok Zagreb 2024-12-21      Croatia
# 2         Dinamo Zagreb             Varazdin 2024-12-21      Croatia
# 3                   QPR              Preston 2024-12-21      England
# 4                 Leeds               Oxford 2024-12-21      England
# 5             Mansfield            Rotherham 2024-12-21      England
# 6             Harrogate              Walsall 2024-12-21      England
# 7          Chesterfield            Wimbledon 2024-12-21      England
# 8              C Palace              Arsenal 2024-12-21      England
# 9                Fulham          Southampton 2024-12-22      England
# 10              Everton              Chelsea 2024-12-22      England
# 11          Dortmund II          Saarbrucken 2024-12-21      Germany
# 12                  Aue          1860 Munich 2024-12-21      Germany
# 13             Mannheim            Bielefeld 2024-12-22      Germany
# 25         Serie B     18                     17                    11
# 26         Serie B     18                     13                     5
# 27         Serie B     18                     20                    20
# 28         Serie B     18                      1                     4
# 29         Serie B     18                      4                    13
# 30  Eerste Divisie     20                      3                     4
# 31  Eerste Divisie     20                     19                    18
# 32      Eredivisie     17                     17                    17
# 33      Eredivisie     17                     15                    14
# 34      Eredivisie     17                     16                    16
# 35      Eredivisie     17                      1                     2
# 36      Primeira L     15                      9                    14
# 37      Primeira L     15                      8                    12
# 38      Primeira L     15                      4                     4
# 39    Championship     18                      1                     1
# 40    Championship     18                     10                    10
# 41       Premier L     18                     10                     8
# 42       Premier L     18                      3                     1
# 43       Premier L     18                      2                     2
# 44       Premier L     18                     12                    10
# 45       Premier L     18                      5                     4
# 46         Primera     18                     10                    11
# 47         Primera     18                      1                     7
# 48         Primera     18                     14                    18
# 49       Super Lig     17                      4                     4
#
#     Away_team_place_total  Away_team_place_away  ...  home_o25  home_o35  \
# 0                       6                     6  ...    33.333     0.000
# 1                       8                     6  ...    50.000    25.000
# 2                       4                     5  ...    62.500    37.500
# 3                      16                    17  ...    45.455    27.273
# 4                      20                    23  ...    54.545    18.182
# 5                      17                    21  ...    44.444    11.111
# 6                       1                     3  ...    50.000    10.000
# 7                       4                     8  ...    50.000    20.000
# 8                       3                     4  ...    25.000    25.000
# 9                      20                    20  ...    75.000    50.000
# 10                      2                     1  ...    57.143    28.571
# 11                      3                     4  ...    77.778    33.333
# 12                     13                     1  ...    77.778    33.333
# 13                      4                     7  ...    62.500    25.000
# 14                      7                     7  ...    66.667    66.667
# 15                      8                    16  ...    71.429    57.143
# 16                      9                     1  ...    50.000    37.500
# 17                      7                     8  ...    71.429    42.857
# 18                     11                     3  ...    50.000    25.000
# 19                     13                    13  ...    71.429    28.571
# 20                      7                     8  ...    57.143    42.857
# 21                     12                    12  ...    42.857    14.286
# 22                      6                     5  ...    71.429    57.143
# 23                     11                     9  ...    33.333    16.667
# 24                     15                    13  ...    62.500    25.000
# 25                     12                    14  ...    55.556    33.333
# 26                     11                     8  ...    12.500     0.000
# 27                     15                    10  ...    37.500    12.500
# 28                      9                     6  ...    62.500    50.000
# 29                     16                    11  ...    25.000    12.500
# 30                     12                     4  ...    66.667    66.667
# 31                      1                     3  ...    30.000    20.000
# 32                     13                    13  ...    75.000    25.000
# 33                     14                    15  ...    62.500    50.000
# 34                      2                     5  ...    50.000    25.000
# 35                      4                     3  ...    85.714    57.143
# 36                     17                    12  ...    14.286    14.286
# 37                     18                    15  ...    14.286     0.000
# 38                      5                     2  ...    28.571     0.000
# 39                      6                     7  ...    62.500    12.500
# 40                      4                     5  ...    37.500    25.000
# 41                      6                     8  ...    55.556    11.111
# 42                      7                     9  ...    50.000    25.000
# 43                      9                    10  ...    55.556    33.333
# 44                     11                     6  ...    37.500    25.000
# 45                      1                     1  ...    50.000    25.000
# 46                     19                    17  ...    75.000    50.000
# 47                      2                     3  ...    71.429    42.857
# 48                     18                    20  ...    50.000    37.500
# 33               Almelo            Groningen 2024-12-21  Netherlands
# 34               Sparta            Amsterdam 2024-12-22  Netherlands
# 35            Eindhoven            Feyenoord 2024-12-22  Netherlands
# 36             Casa Pia               Arouca 2024-12-20     Portugal
# 37            Famalicao              Farense 2024-12-21     Portugal
# 38          Santa Clara                Braga 2024-12-22     Portugal
# 39              Falkirk             Hamilton 2024-12-21     Scotland
# 40        Airdrieonians      Partick Thistle 2024-12-21     Scotland
# 41          Ross County           St. Mirren 2024-12-21     Scotland
# 42              Rangers               Dundee 2024-12-21     Scotland
# 43             Aberdeen                 Hibs 2024-12-21     Scotland
# 44  Heart of Midlothian            Johnstone 2024-12-22     Scotland
# 45        Dundee United               Celtic 2024-12-22     Scotland
# 46               Girona           Valladolid 2024-12-20        Spain
# 47            Barcelona             Atletico 2024-12-21        Spain
# 48           Las Palmas             Espanyol 2024-12-22        Spain
# 49             Eyupspor           Fenerbahce 2024-12-20       Turkey
#
#             League  Round  Home_team_place_total  Home_team_place_home  \
# 0       Pro League     19                      9                     5
# 1       Division 1     18                     10                     4
# 2       Division 1     18                      3                     5
# 3     Championship     22                     18                    22
# 4     Championship     22                      2                     1
# 5       League One     21                     11                    18
# 6       League Two     21                     20                    19
# 7       League Two     21                      6                    12
# 8        Premier L     17                     15                    17
# 9        Premier L     17                      8                    10
# 10       Premier L     17                     16                    15
# 11      3rd League     19                     10                     6
# 12      3rd League     19                      9                    14
# 13      3rd League     19                     15                    13
# 14      Bundesliga     15                      3                     5
# 15      Bundesliga     15                     10                    13
# 16    Bundesliga 2     17                      4                    12
# 17    Bundesliga 2     17                      3                     5
# 18    Bundesliga 2     17                      5                     1
# 19         Super L     16                      1                     3
# 20         Super L     16                      3                     6
# 21         Super L     16                      2                     2
# 22         Super L     16                     11                     9
# 23  Premier League     15                      2                     4
# 24         Serie A     17                     12                     9
# 25         Serie B     18                     17                    11
# 26         Serie B     18                     13                     5
# 27         Serie B     18                     20                    20
# 28         Serie B     18                      1                     4
# 29         Serie B     18                      4                    13
# 30  Eerste Divisie     20                      3                     4
# 31  Eerste Divisie     20                     19                    18
# 32      Eredivisie     17                     17                    17
# 33      Eredivisie     17                     15                    14
# 34      Eredivisie     17                     16                    16
# 35      Eredivisie     17                      1                     2
# 36      Primeira L     15                      9                    14
# 37      Primeira L     15                      8                    12
# 38      Primeira L     15                      4                     4
# 39    Championship     18                      1                     1
# 40    Championship     18                     10                    10
# 41       Premier L     18                     10                     8
# 42       Premier L     18                      3                     1
# 43       Premier L     18                      2                     2
# 44       Premier L     18                     12                    10
# 45       Premier L     18                      5                     4
# 46         Primera     18                     10                    11
# 47         Primera     18                      1                     7
# 48         Primera     18                     14                    18
# 49       Super Lig     17                      4                     4
#
#     Away_team_place_total  Away_team_place_away  ...  home_o25  home_o35  \
# 0                       6                     6  ...    33.333     0.000
# 1                       8                     6  ...    50.000    25.000
# 2                       4                     5  ...    62.500    37.500
# 3                      16                    17  ...    45.455    27.273
# 4                      20                    23  ...    54.545    18.182
# 5                      17                    21  ...    44.444    11.111
# 6                       1                     3  ...    50.000    10.000
# 7                       4                     8  ...    50.000    20.000
# 8                       3                     4  ...    25.000    25.000
# 9                      20                    20  ...    75.000    50.000
# 10                      2                     1  ...    57.143    28.571
# 11                      3                     4  ...    77.778    33.333
# 12                     13                     1  ...    77.778    33.333
# 13                      4                     7  ...    62.500    25.000
# 14                      7                     7  ...    66.667    66.667
# 15                      8                    16  ...    71.429    57.143
# 16                      9                     1  ...    50.000    37.500
# 17                      7                     8  ...    71.429    42.857
# 18                     11                     3  ...    50.000    25.000
# 19                     13                    13  ...    71.429    28.571
# 20                      7                     8  ...    57.143    42.857
# 21                     12                    12  ...    42.857    14.286
# 22                      6                     5  ...    71.429    57.143
# 23                     11                     9  ...    33.333    16.667
# 24                     15                    13  ...    62.500    25.000
# 25                     12                    14  ...    55.556    33.333
# 26                     11                     8  ...    12.500     0.000
# 27                     15                    10  ...    37.500    12.500
# 28                      9                     6  ...    62.500    50.000
# 29                     16                    11  ...    25.000    12.500
# 30                     12                     4  ...    66.667    66.667
# 31                      1                     3  ...    30.000    20.000
# 32                     13                    13  ...    75.000    25.000
# 33                     14                    15  ...    62.500    50.000
# 34                      2                     5  ...    50.000    25.000
# 35                      4                     3  ...    85.714    57.143
# 36                     17                    12  ...    14.286    14.286
# 37                     18                    15  ...    14.286     0.000
# 38                      5                     2  ...    28.571     0.000
# 39                      6                     7  ...    62.500    12.500
# 40                      4                     5  ...    37.500    25.000
# 41                      6                     8  ...    55.556    11.111
# 42                      7                     9  ...    50.000    25.000
# 43                      9                    10  ...    55.556    33.333
# 44                     11                     6  ...    37.500    25.000
# 45                      1                     1  ...    50.000    25.000
# 46                     19                    17  ...    75.000    50.000
# 47                      2                     3  ...    71.429    42.857
# 48                     18                    20  ...    50.000    37.500
# 49                      2                     2  ...    57.143    28.571
#
#     home_scored  away_win  away_win_15  away_o25  away_o35  away_scored  \
# 0         1.000    22.222       11.111    44.444    33.333        1.000
# 1         1.250    25.000       25.000    75.000    37.500        1.250
# 2         2.250    12.500        0.000    25.000     0.000        0.625
# 3         1.182    10.000       10.000    50.000    40.000        1.000
# 4         2.273     0.000        0.000    55.556    22.222        0.778
# 5         1.333    11.111        0.000    11.111    11.111        0.667
# 6         0.900    55.556       33.333    33.333    33.333        1.556
# 7         1.400    44.444       33.333    33.333    22.222        1.222
# 8         0.750    37.500       25.000    25.000    25.000        1.500
# 9         1.750     0.000        0.000    37.500    37.500        0.500
# 10        1.286    75.000       37.500    75.000    37.500        2.875
# 11        2.000    44.444       11.111    33.333    33.333        1.444
# 12        1.556    55.556       22.222    77.778    33.333        1.778
# 13        1.500    33.333       22.222    66.667    22.222        1.111
# 14        3.000    50.000       33.333    83.333    50.000        2.500
# 15        1.857     0.000        0.000    66.667    33.333        0.833
# 16        1.500    75.000       25.000    87.500    50.000        2.125
