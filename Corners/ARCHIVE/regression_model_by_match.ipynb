# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"/Corners/ARCHIVE/Data/master_db_eng1_20_25_by_match.csv")
data = data[data["round"]>7]
data["total_corners"]=data["corners_home"]+data["corners_away"]
data
# Out:
#      country  season        date  ko_time  round    home_team  away_team  \
# 68      Eng1      21  2020-11-06     2000      8  Southampton  Newcastle
# 69      Eng1      21  2020-11-06     1730      8     Brighton    Burnley
# 70      Eng1      21  2020-11-07     1500      8     C Palace      Leeds
# 71      Eng1      21  2020-11-07     1730      8      Chelsea  Sheff Utd
# 72      Eng1      21  2020-11-07     2000      8     West Ham     Fulham
# ...      ...     ...         ...      ...    ...          ...        ...
# 1744    Eng1      25  2025-01-25     1500     23       Wolves    Arsenal
# 1745    Eng1      25  2025-01-26     1630     23  Aston Villa   West Ham
# 1746    Eng1      25  2025-01-26     1400     23     C Palace  Brentford
# 1747    Eng1      25  2025-01-26     1900     23       Fulham    Man Utd
# 1748    Eng1      25  2025-01-26     1400     23    Tottenham  Leicester
#
#       home_goals_ft  away_goals_ft  home_goals_ht  ...  \
# 68                2              0              1  ...
# 69                0              0              0  ...
# 70                4              1              3  ...
# 71                4              1              2  ...
# 72                1              0              0  ...
# ...             ...            ...            ...  ...
# 1744              0              1              0  ...
# 1745              1              1              1  ...
# 1746              1              2              0  ...
# 1747              0              1              0  ...
# 1748              1              2              1  ...
#
#       running_avg_window5_away_shots_on_target_away  \
# 68                                              NaN
# 69                                              NaN
# 70                                              NaN
# 71                                              NaN
# 72                                              NaN
# ...                                             ...
# 1744                                            5.0
# 1745                                            5.0
# 1746                                            4.2
# 1747                                            3.4
# 1748                                            2.4
#
#       running_avg_window5_possession_home  \
# 68                                   52.6
# 69                                   56.4
# 70                                   35.2
# 71                                   58.2
# 72                                   35.0
# ...                                   ...
# 1744                                 44.4
# 1745                                 41.6
# 1746                                 44.0
# 1747                                 52.2
# 1748                                 61.4
#
#       running_avg_window5_possession_away  \
# 68                                   37.2
# 69                                   40.2
# 70                                   62.2
# 71                                   35.4
# 72                                   54.6
# ...                                   ...
# 1744                                 58.4
# 1745                                 49.4
# 1746                                 44.4
# 1747                                 51.2
# 1748                                 40.2
#
#       running_avg_window5_home_possession_home  \
# 68                                         NaN
# 69                                         NaN
# 70                                         NaN
# 71                                         NaN
# 72                                         NaN
# ...                                        ...
# 1744                                      50.8
# 1745                                      52.4
# 1746                                      41.2
# 1747                                      51.8
# 1748                                      49.0
#
#       running_avg_window5_away_possession_away  \
# 68                                         NaN
# 69                                         NaN
# 70                                         NaN
# 71                                         NaN
# 72                                         NaN
# ...                                        ...
# 1744                                      58.4
# 1745                                      49.4
# 1746                                      44.4
# 1747                                      51.2
# 1748                                      40.2
#
#       running_avg_window5_points_home  running_avg_window5_points_away  \
# 68                                2.0                              1.6
# 69                                1.0                              0.2
# 70                                1.4                              1.2
# 71                                1.8                              0.2
# 72                                1.0                              0.8
# ...                               ...                              ...
# 1744                              0.8                              2.2
# 1745                              0.8                              1.4
# 1746                              2.6                              1.0
# 1747                              1.6                              1.0
# 1748                              0.6                              0.0
#
#       running_avg_window5_home_points_home  \
# 68                                     NaN
# 69                                     NaN
# 70                                     NaN
# 71                                     NaN
# 72                                     NaN
# ...                                    ...
# 1744                                   1.2
# 1745                                   2.6
# 1746                                   1.2
# 1747                                   1.4
# 1748                                   0.4
#
#       running_avg_window5_away_points_away  total_corners
# 68                                     NaN             10
# 69                                     NaN              8
# 70                                     NaN              9
# 71                                     NaN             13
# 72                                     NaN             14
# ...                                    ...            ...
# 1744                                   2.2              6
# 1745                                   1.4              7
# 1746                                   1.0             11
# 1747                                   1.0              3
# 1748                                   0.0             10
#
# [1399 rows x 125 columns]

# %%
data.dropna(inplace=True)
data
# Out:
#      country  season        date  ko_time  round      home_team  away_team  \
# 99      Eng1      21  2020-12-05     2100     11        Chelsea      Leeds
# 102     Eng1      21  2020-12-06     1200     11  West Bromwich   C Palace
# 103     Eng1      21  2020-12-06     1630     11      Tottenham    Arsenal
# 104     Eng1      21  2020-12-06     1415     11      Sheff Utd  Leicester
# 105     Eng1      21  2020-12-06     1915     11      Liverpool     Wolves
# ...      ...     ...         ...      ...    ...            ...        ...
# 1744    Eng1      25  2025-01-25     1500     23         Wolves    Arsenal
# 1745    Eng1      25  2025-01-26     1630     23    Aston Villa   West Ham
# 1746    Eng1      25  2025-01-26     1400     23       C Palace  Brentford
# 1747    Eng1      25  2025-01-26     1900     23         Fulham    Man Utd
# 1748    Eng1      25  2025-01-26     1400     23      Tottenham  Leicester
#
#       home_goals_ft  away_goals_ft  home_goals_ht  ...  \
# 99                3              1              1  ...
# 102               1              5              1  ...
# 103               2              0              2  ...
# 104               1              2              1  ...
# 105               4              0              1  ...
# ...             ...            ...            ...  ...
# 1744              0              1              0  ...
# 1745              1              1              1  ...
# 1746              1              2              0  ...
# 1747              0              1              0  ...
# 1748              1              2              1  ...
#
#       running_avg_window5_away_shots_on_target_away  \
# 99                                              6.2
# 102                                             4.4
# 103                                             3.2
# 104                                             5.6
# 105                                             3.2
# ...                                             ...
# 1744                                            5.0
# 1745                                            5.0
# 1746                                            4.2
# 1747                                            3.4
# 1748                                            2.4
#
#       running_avg_window5_possession_home  \
# 99                                   61.8
# 102                                  41.8
# 103                                  54.0
# 104                                  36.4
# 105                                  58.8
# ...                                   ...
# 1744                                 44.4
# 1745                                 41.6
# 1746                                 44.0
# 1747                                 52.2
# 1748                                 61.4
#
#       running_avg_window5_possession_away  \
# 99                                   59.8
# 102                                  39.2
# 103                                  42.2
# 104                                  42.2
# 105                                  46.8
# ...                                   ...
# 1744                                 58.4
# 1745                                 49.4
# 1746                                 44.4
# 1747                                 51.2
# 1748                                 40.2
#
#       running_avg_window5_home_possession_home  \
# 99                                        58.8
# 102                                       41.4
# 103                                       49.4
# 104                                       43.6
# 105                                       60.8
# ...                                        ...
# 1744                                      50.8
# 1745                                      52.4
# 1746                                      41.2
# 1747                                      51.8
# 1748                                      49.0
#
#       running_avg_window5_away_possession_away  \
# 99                                        59.8
# 102                                       39.2
# 103                                       42.2
# 104                                       42.2
# 105                                       46.8
# ...                                        ...
# 1744                                      58.4
# 1745                                      49.4
# 1746                                      44.4
# 1747                                      51.2
# 1748                                      40.2
#
#       running_avg_window5_points_home  running_avg_window5_points_away  \
# 99                                2.2                              1.8
# 102                               0.2                              1.2
# 103                               2.6                              1.4
# 104                               0.0                              2.4
# 105                               1.2                              1.8
# ...                               ...                              ...
# 1744                              0.8                              2.2
# 1745                              0.8                              1.4
# 1746                              2.6                              1.0
# 1747                              1.6                              1.0
# 1748                              0.6                              0.0
#
#       running_avg_window5_home_points_home  \
# 99                                     1.6
# 102                                    1.0
# 103                                    1.6
# 104                                    0.2
# 105                                    3.0
# ...                                    ...
# 1744                                   1.2
# 1745                                   2.6
# 1746                                   1.2
# 1747                                   1.4
# 1748                                   0.4
#
#       running_avg_window5_away_points_away  total_corners
# 99                                     1.8             12
# 102                                    1.2             10
# 103                                    1.4             12
# 104                                    2.4             11
# 105                                    1.8             10
# ...                                    ...            ...
# 1744                                   2.2              6
# 1745                                   1.4              7
# 1746                                   1.0             11
# 1747                                   1.0              3
# 1748                                   0.0             10
#
# [1227 rows x 125 columns]

# %%
# Define the columns to drop
columns_to_drop = [
    "shots_home", "shots_home_1h", "shots_home_2h",
    "shots_away", "shots_away_1h", "shots_away_2h",
    "shots_on_target_home", "shots_on_target_home_1h", "shots_on_target_home_2h",
    "shots_on_target_away", "shots_on_target_away_1h", "shots_on_target_away_2h",
    "corners_home", "corners_home_1h", "corners_home_2h",
    "corners_away", "corners_away_1h", "corners_away_2h",
    "fouls_home", "fouls_home_1h", "fouls_home_2h",
    "fouls_away", "fouls_away_1h", "fouls_away_2h",
    "yellow_cards_home", "yellow_cards_home_1h", "yellow_cards_home_2h",
    "yellow_cards_away", "yellow_cards_away_1h", "yellow_cards_away_2h",
    "possession_home", "possession_home_1h", "possession_home_2h",
    "possession_away", "possession_away_1h", "possession_away_2h",
    "goals_scored_total_home", "goals_conceded_total_home",
    "goals_scored_total_away", "goals_conceded_total_away", "country", "season", "date", "ko_time", "home_team", "away_team", "home_goals_ft", "away_goals_ft", "home_goals_ht", "away_goals_ht", "points_home", "points_away",
]

# Drop the specified columns
data = data.drop(columns=columns_to_drop, errors='ignore')
data
# Out:
#       round  home_team_place_total  home_team_place_home  \
# 99       11                    3.0                   4.0
# 102      11                   18.0                  15.0
# 103      11                    1.0                   5.0
# 104      11                   20.0                  20.0
# 105      11                    2.0                   1.0
# ...     ...                    ...                   ...
# 1744     23                   17.0                  18.0
# 1745     23                    8.0                   4.0
# 1746     23                   12.0                  16.0
# 1747     23                   10.0                  10.0
# 1748     23                   15.0                  13.0
#
#       away_team_place_total  away_team_place_away  home_odds  draw_odds  \
# 99                     12.0                   6.0       1.55       4.60
# 102                    15.0                  16.0       3.04       3.32
# 103                    14.0                  14.0       2.04       3.58
# 104                     4.0                   3.0       3.85       3.56
# 105                     7.0                   8.0       1.55       4.24
# ...                     ...                   ...        ...        ...
# 1744                    2.0                   4.0       5.93       4.15
# 1745                   14.0                  12.0       1.48       4.85
# 1746                   11.0                  18.0       1.97       3.80
# 1747                   13.0                  14.0       2.40       3.55
# 1748                   19.0                  19.0       1.51       5.05
#
#       away_odds  elo_home  elo_away  ...  \
# 99         6.12      1908      1718  ...
# 102        2.56      1546      1653  ...
# 103        3.96      1951      1780  ...
# 104        2.07      1596      1815  ...
# 105        7.00      2048      1824  ...
# ...         ...       ...       ...  ...
# 1744       1.61      1583      1991  ...
# 1745       6.85      1782      1639  ...
# 1746       3.84      1778      1678  ...
# 1747       3.03      1756      1637  ...
# 1748       5.85      1707      1446  ...
#
#       running_avg_window5_away_shots_on_target_away  \
# 99                                              6.2
# 102                                             4.4
# 103                                             3.2
# 104                                             5.6
# 105                                             3.2
# ...                                             ...
# 1744                                            5.0
# 1745                                            5.0
# 1746                                            4.2
# 1747                                            3.4
# 1748                                            2.4
#
#       running_avg_window5_possession_home  \
# 99                                   61.8
# 102                                  41.8
# 103                                  54.0
# 104                                  36.4
# 105                                  58.8
# ...                                   ...
# 1744                                 44.4
# 1745                                 41.6
# 1746                                 44.0
# 1747                                 52.2
# 1748                                 61.4
#
#       running_avg_window5_possession_away  \
# 99                                   59.8
# 102                                  39.2
# 103                                  42.2
# 104                                  42.2
# 105                                  46.8
# ...                                   ...
# 1744                                 58.4
# 1745                                 49.4
# 1746                                 44.4
# 1747                                 51.2
# 1748                                 40.2
#
#       running_avg_window5_home_possession_home  \
# 99                                        58.8
# 102                                       41.4
# 103                                       49.4
# 104                                       43.6
# 105                                       60.8
# ...                                        ...
# 1744                                      50.8
# 1745                                      52.4
# 1746                                      41.2
# 1747                                      51.8
# 1748                                      49.0
#
#       running_avg_window5_away_possession_away  \
# 99                                        59.8
# 102                                       39.2
# 103                                       42.2
# 104                                       42.2
# 105                                       46.8
# ...                                        ...
# 1744                                      58.4
# 1745                                      49.4
# 1746                                      44.4
# 1747                                      51.2
# 1748                                      40.2
#
#       running_avg_window5_points_home  running_avg_window5_points_away  \
# 99                                2.2                              1.8
# 102                               0.2                              1.2
# 103                               2.6                              1.4
# 104                               0.0                              2.4
# 105                               1.2                              1.8
# ...                               ...                              ...
# 1744                              0.8                              2.2
# 1745                              0.8                              1.4
# 1746                              2.6                              1.0
# 1747                              1.6                              1.0
# 1748                              0.6                              0.0
#
#       running_avg_window5_home_points_home  \
# 99                                     1.6
# 102                                    1.0
# 103                                    1.6
# 104                                    0.2
# 105                                    3.0
# ...                                    ...
# 1744                                   1.2
# 1745                                   2.6
# 1746                                   1.2
# 1747                                   1.4
# 1748                                   0.4
#
#       running_avg_window5_away_points_away  total_corners
# 99                                     1.8             12
# 102                                    1.2             10
# 103                                    1.4             12
# 104                                    2.4             11
# 105                                    1.8             10
# ...                                    ...            ...
# 1744                                   2.2              6
# 1745                                   1.4              7
# 1746                                   1.0             11
# 1747                                   1.0              3
# 1748                                   0.0             10
#
# [1227 rows x 73 columns]
